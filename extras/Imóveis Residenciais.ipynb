# %% [markdown]
# # Relatório de Análise III

# %% [markdown]
# # Imóveis Residenciais

# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/aluguel.csv' , sep =';')

# %%
dados.head(10)
# Out:
#           Tipo                   Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0  Apartamento                   Centro        1      0       0    15   800.0
# 1  Apartamento             Higienópolis        1      0       0    48   800.0
# 2  Apartamento                 Cachambi        2      0       0    50  1300.0
# 3  Apartamento                   Grajaú        2      1       0    70  1500.0
# 4  Apartamento      Lins de Vasconcelos        3      1       1    90  1500.0
# 5  Apartamento               Copacabana        1      0       1    40  2000.0
# 6  Apartamento  Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 7  Apartamento          Barra da Tijuca        2      1       1    67  1700.0
# 8  Apartamento                   Tijuca        2      1       0   110  1900.0
# 9  Apartamento                   Olaria        3      1       0    68  1000.0
#
#    Condominio   IPTU  Valor m2 Tipo Agregado
# 0       390.0   20.0     53.33   Apartamento
# ...

# %%
list(dados['Tipo'].drop_duplicates())
# Out:
# ['Apartamento', 'Casa', 'Casa de Condomínio', 'Casa de Vila', 'Quitinete']

# %%
residencial = ['Apartamento', 'Casa', 'Casa de Condomínio', 'Casa de Vila', 'Quitinete']
residencial
# Out:
# ['Apartamento', 'Casa', 'Casa de Condomínio', 'Casa de Vila', 'Quitinete']

# %%
dados.head(10)
# Out:
#           Tipo                   Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0  Apartamento                   Centro        1      0       0    15   800.0
# 1  Apartamento             Higienópolis        1      0       0    48   800.0
# 2  Apartamento                 Cachambi        2      0       0    50  1300.0
# 3  Apartamento                   Grajaú        2      1       0    70  1500.0
# 4  Apartamento      Lins de Vasconcelos        3      1       1    90  1500.0
# 5  Apartamento               Copacabana        1      0       1    40  2000.0
# 6  Apartamento  Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 7  Apartamento          Barra da Tijuca        2      1       1    67  1700.0
# 8  Apartamento                   Tijuca        2      1       0   110  1900.0
# 9  Apartamento                   Olaria        3      1       0    68  1000.0
#
#    Condominio   IPTU  Valor m2 Tipo Agregado
# 0       390.0   20.0     53.33   Apartamento
# ...

# %%
selecao = dados['Tipo'].isin(residencial).head(10) #isin nos retorna um DataFrame de booleanos, ou seja de Trues e Falses
selecao
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# 8    True
# 9    True
# Name: Tipo, dtype: bool

# %%
list(dados_residencial['Tipo'].drop_duplicates())
# Out:
# ['Apartamento', 'Casa', 'Casa de Condomínio', 'Casa de Vila', 'Quitinete']

# %%
dados_residencial.shape[0]
# Out:
# 19831

# %%
dados_residencial.index = range(dados_residencial.shape[0])

# %%
dados.shape[0]
# Out:
# 19831

# %%
import pandas as pd    #

numeros = [i for i in range(11)]
letras = [chr(i + 65) for i in range(11)]
nome_coluna = ['N']

df = pd.DataFrame(data = numeros, index = letras, columns = nome_coluna)

selecao = df['N'].isin([i for i in range(11) if i % 2 == 0])
df = df[selecao]
df

#O código cria um DataFrame com uma coluna chamda N e atribui os números de 0 até 10. Com o método isin()
# selecionamos somente os números pares de N.
# Out:
#     N
# A   0
# C   2
# E   4
# G   6
# I   8
# K  10

# %% [markdown]
# ## Exportando a base de dados

# %%
dados_residencial.to_csv('dados/aluguel_residencial.csv', sep =';')   #usamos o to_csv para importação de dados

# %%
dados_residencial_2 = pd.read_csv('dados/aluguel_residencial.csv', sep =';')

# %%
dados_residencial_2
# Out:
#        Unnamed: 0         Tipo               Bairro  Quartos  Vagas  Suites  \
# 0               0  Apartamento               Centro        1      0       0
# 1               1  Apartamento         Higienópolis        1      0       0
# 2               2  Apartamento             Cachambi        2      0       0
# 3               3  Apartamento               Grajaú        2      1       0
# 4               4  Apartamento  Lins de Vasconcelos        3      1       1
# ...           ...          ...                  ...      ...    ...     ...
# 19826       19826    Quitinete               Glória        1      0       0
# 19827       19827    Quitinete             Flamengo        1      0       0
# 19828       19828    Quitinete               Centro        1      0       0
# 19829       19829    Quitinete           Copacabana        1      0       0
# 19830       19830    Quitinete               Centro        0      0       0
#
# ...

# %%
dados_residencial.to_csv('dados/aluguel_residencial.csv', sep =';', index = False)   #index igual a False para remover o indice do DataFrame

# %%
dados_residencial_2 = pd.read_csv('dados/aluguel_residencial.csv', sep =';')

# %%
dados_residencial_2
# Out:
#               Tipo               Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0      Apartamento               Centro        1      0       0    15   800.0
# 1      Apartamento         Higienópolis        1      0       0    48   800.0
# 2      Apartamento             Cachambi        2      0       0    50  1300.0
# 3      Apartamento               Grajaú        2      1       0    70  1500.0
# 4      Apartamento  Lins de Vasconcelos        3      1       1    90  1500.0
# ...            ...                  ...      ...    ...     ...   ...     ...
# 19826    Quitinete               Glória        1      0       0    10   400.0
# 19827    Quitinete             Flamengo        1      0       0    23   900.0
# 19828    Quitinete               Centro        1      0       0    24  1100.0
# 19829    Quitinete           Copacabana        1      0       0    22  1500.0
# 19830    Quitinete               Centro        0      0       0    27   800.0
#
# ...
