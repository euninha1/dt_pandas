# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv('dados/aluguel_amostra.csv', sep=';')

# %%
dados.head(10)
# Out:
#           Tipo                    Bairro  Quartos  Vagas  Suites  Area  \
# 0  Apartamento  Recreio dos Bandeirantes        3      2       1   320
# 1  Apartamento                  Maracanã        2      0       0    59
# 2  Apartamento                    Leblon        3      2       1   147
# 3  Apartamento               São Conrado        3      3       3   270
# 4  Apartamento                    Tijuca        2      1       0    65
# 5  Apartamento                  Cachambi        2      1       1    75
# 6  Apartamento                    Glória        1      0       0    52
# 7  Apartamento              Engenho Novo        2      1       0    70
# 8  Apartamento                  Maracanã        1      1       0    59
# 9  Apartamento                  Flamengo        3      0       0   100
#
#      Valor  Condominio    IPTU  Valor m2 Tipo Agregado
# 0   3200.0      1319.0     0.0     10.00   Apartamento
# 1    800.0       725.0    47.0     13.56   Apartamento
# 2   7500.0      1000.0   381.0     51.02   Apartamento
# 3  14999.0      2800.0  1200.0     55.55   Apartamento
# 4   1200.0       640.0    97.0     18.46   Apartamento
# 5   1400.0       715.0     0.0     18.67   Apartamento
# 6   1700.0       560.0     0.0     32.69   Apartamento
# 7   1200.0       430.0    21.0     17.14   Apartamento
# 8   1500.0       410.0     0.0     25.42   Apartamento
# 9   2500.0       980.0   105.0     25.00   Apartamento

# %%
# %matplotlib inline 
import pandas as pd 
import matplotlib.pyplot as plt 
plt.rc('figure', figsize = (10, 4))

# %%
dados.boxplot(['Valor'])
# Out:
# <Axes: >

# %%
dados[dados['Valor'] >= 5000]
# Out:
#              Tipo       Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 2     Apartamento       Leblon        3      2       1   147   7500.0
# 3     Apartamento  São Conrado        3      3       3   270  14999.0
# 12    Apartamento       Leblon        4      2       1   200  12000.0
# 18    Apartamento     Flamengo        3      1       1   250   8000.0
# 20    Apartamento     Flamengo        4      1       2   150   6000.0
# ...           ...          ...      ...    ...     ...   ...      ...
# 9980  Apartamento      Ipanema        4      3       4   175  25000.0
# 9986  Apartamento       Leblon        3      2       1   102   7500.0
# 9994  Apartamento       Leblon        2      1       2   150   8000.0
# 9995  Apartamento   Copacabana        3      1       2   160  15500.0
# 9996  Apartamento   Copacabana        4      0       0   190   6000.0
#
#       Condominio    IPTU  Valor m2 Tipo Agregado
# 2         1000.0   381.0     51.02   Apartamento
# 3         2800.0  1200.0     55.55   Apartamento
# 12        2340.0   660.0     60.00   Apartamento
# 18        2000.0   580.0     32.00   Apartamento
# 20        1700.0  1100.0     40.00   Apartamento
# ...          ...     ...       ...           ...
# 9980      3750.0  1200.0    142.86   Apartamento
# 9986      2092.0   420.0     73.53   Apartamento
# 9994      1160.0   500.0     53.33   Apartamento
# 9995      1600.0   435.0     96.88   Apartamento
# 9996      1000.0     0.0     31.58   Apartamento
#
# [2818 rows x 11 columns]

# %%
valor = dados['Valor']

# %%
q1 = valor.quantile(.25)
q1
# Out:
# 1600.0

# %%
q1 = valor.quantile(.25)
q3 = valor.quantile(.75)
IIQ = q3 - q1 
limite_inferior = q1 - 1.5 * IIQ
limite_superior = q3 + 1.5 * IIQ

# %%
selecao = (valor >= limite_inferior) & (valor <= limite_superior) 
dados_new = dados[selecao]

# %%
q3 = valor.quantile(.75)
q3
# Out:
# 5500.0

# %%
#respostas

[Q1] → 21.25
[Q3] → 42.31
[IIQ] → 21.06
[Q1 - 1.5 * IIQ] → -10.34
[Q3 + 1.5 * IIQ] → 73.90
# Out:
#   Cell In[12], line 3
#     [Q1] → 21.25
#          ^
# SyntaxError: invalid character '→' (U+2192)
