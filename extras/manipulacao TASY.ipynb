# %% [markdown]
# # Relatório Análise Jupyter com o Tasy

# %%
# informe quais os setores teve mais atendimento dc ambulatorio ou centro de endoscopia 

# informe qual o setor que teve mais valores e informe o valor mais alto e o valor mais baixo 


# informe o convenio mais utilizado 

# e o usuário que mais fez o atneidmento

# %%
import pandas as pd

# %%
dados = pd.read_excel('dados/manipulacao.xlsx')
dados
# Out:
#      Atendimento                           Paciente  \
# 0         323785                   Tania Maria Pena
# 1         324464             Vitor Mateus Neves Luz
# 2         322304           Jose Petronio de Almeida
# 3         322389       Maria Zely de Oliveira Viana
# 4         322509              Valter Cesar de Jesus
# ..           ...                                ...
# 456       323350    Josefa Ednalva dos Reis Santana
# 457       323762  Maria Cecilia Oliveira dos Santos
# 458       324264          Josefa Batista de Almeida
# 459       324476            Jose Oliveira Reis Neto
# 460       323562                       Teste Soneca
#
#                                        Setor     Valor    Data Atendimento  \
# 0                           Centro Cirurgico      0.00 2023-07-12 15:00:00
# 1                           Centro Cirurgico    158.21 2023-07-15 08:00:00
# 2                            DC  Ambulatorio   7673.41 2023-07-03 06:00:00
# ...
